# %%
import numpy as np

# %%
# selesaikan soal berikut
x = np.array([[25],
                   [2],
                   [-3],
                   [-23]])
x
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
transpose_x = x.T
transpose_x
# Out:
# array([[ 25,   2,  -3, -23]])
