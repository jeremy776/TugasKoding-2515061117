# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
X = np.array([[117, 711, 171], [711, 171, 117]])
# tampilkan ukuran dari matrix X
X.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
X[:, 0]
# Out:
# array([117, 711])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
X[1]
# Out:
# array([711, 171, 117])

# %%
# ulangi soal nomor 1 menggunakan pytorch
import torch

# %%
X_pt = torch.tensor([[117, 711, 171], [711, 171, 117]])
X_pt
# Out:
# tensor([[117, 711, 171],
#         [711, 171, 117]])

# %%
X_pt.shape
# Out:
# torch.Size([2, 3])

# %%
X_pt[:, 0]
# Out:
# tensor([117, 711])

# %%
X_pt[1]
# Out:
# tensor([711, 171, 117])

# %%
# ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf

# %%
X_tf = tf.Variable([[117, 711, 171], [711, 171, 117]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[117, 711, 171],
#        [711, 171, 117]], dtype=int32)>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 3], dtype=int32)>

# %%
X_tf[:,0]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([117, 711], dtype=int32)>

# %%
X_tf[1]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([711, 171, 117], dtype=int32)>
